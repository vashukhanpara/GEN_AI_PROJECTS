# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\Users\ADMIN\miniconda3\envs\ann_env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[8017, 5074, 4900, 2628],
#  [8017, 5074, 4900, 9858],
#  [8017, 6999, 4900, 3554],
#  [8329, 2152, 713, 3446, 5508],
#  [8329, 2152, 713, 3446, 4945],
#  [2540, 8017, 546, 4900, 8370],
#  [7700, 3303, 4578, 3446]]

# %%
## word Embedding Representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences  
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 8017 5074 4900 2628]
#  [   0    0    0    0 8017 5074 4900 9858]
#  [   0    0    0    0 8017 6999 4900 3554]
#  [   0    0    0 8329 2152  713 3446 5508]
#  [   0    0    0 8329 2152  713 3446 4945]
#  [   0    0    0 2540 8017  546 4900 8370]
#  [   0    0    0    0 7700 3303 4578 3446]]

# %%
dim=11

# %%
# Create a Sequential model
model = Sequential()

model.add(Embedding(input_dim=voc_size, output_dim=dim, input_length=sent_length))
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From c:\Users\ADMIN\miniconda3\envs\ann_env\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\ADMIN\miniconda3\envs\ann_env\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 11)             110000
#
# =================================================================
# Total params: 110000 (429.69 KB)
# Trainable params: 110000 (429.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 259ms/step
# array([[[-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [ 0.0318701 , -0.00532025, -0.00605241, -0.0339821 ,
#          -0.00912648, -0.04877807, -0.04505664, -0.01691036,
#          -0.00612581,  0.03406263, -0.00399526],
#         [-0.01703254,  0.04785147,  0.02648509, -0.00462043,
#           0.02795117,  0.03423065, -0.03556865, -0.00616516,
#           0.03057313, -0.0242242 , -0.03303735],
#         [ 0.02684161, -0.03010103,  0.03541192,  0.0107309 ,
#          -0.03425664,  0.01833472, -0.04546411,  0.00071859,
#          -0.04674624,  0.04128278,  0.03694728],
#         [ 0.00308528,  0.03357005,  0.01008511,  0.00702189,
#           0.01246371, -0.02947147,  0.00230737, -0.03540866,
#           0.01437571,  0.0148119 ,  0.00897276]],
#
#        [[-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [ 0.0318701 , -0.00532025, -0.00605241, -0.0339821 ,
#          -0.00912648, -0.04877807, -0.04505664, -0.01691036,
#          -0.00612581,  0.03406263, -0.00399526],
#         [-0.01703254,  0.04785147,  0.02648509, -0.00462043,
#           0.02795117,  0.03423065, -0.03556865, -0.00616516,
#           0.03057313, -0.0242242 , -0.03303735],
#         [ 0.02684161, -0.03010103,  0.03541192,  0.0107309 ,
#          -0.03425664,  0.01833472, -0.04546411,  0.00071859,
#          -0.04674624,  0.04128278,  0.03694728],
#         [ 0.00865852,  0.02141055,  0.01096357,  0.00886985,
#          -0.01010636,  0.0420646 , -0.00927234,  0.03388772,
#          -0.04792137, -0.00994275, -0.00489676]],
#
#        [[-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [ 0.0318701 , -0.00532025, -0.00605241, -0.0339821 ,
#          -0.00912648, -0.04877807, -0.04505664, -0.01691036,
#          -0.00612581,  0.03406263, -0.00399526],
#         [ 0.01460835,  0.01213656,  0.04066975, -0.01182304,
#          -0.04888467,  0.00233509, -0.02044531,  0.03966038,
#           0.03068494,  0.008045  ,  0.00256196],
#         [ 0.02684161, -0.03010103,  0.03541192,  0.0107309 ,
#          -0.03425664,  0.01833472, -0.04546411,  0.00071859,
#          -0.04674624,  0.04128278,  0.03694728],
#         [-0.03381888,  0.04894734, -0.04669833,  0.01169314,
#           0.04785308, -0.03768538,  0.04509595,  0.04810603,
#           0.01283551,  0.03947424,  0.00757109]],
#
#        [[-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [ 0.03209147, -0.00561028,  0.00539353,  0.03247753,
#           0.00468925,  0.01512692,  0.04685165,  0.03980324,
#           0.01631924, -0.01047086, -0.02139553],
#         [ 0.02716657,  0.03850276, -0.03751949,  0.04166797,
#          -0.00788311, -0.01884303,  0.02259257, -0.01319508,
#          -0.03009067, -0.0170976 , -0.02252989],
#         [-0.04967133,  0.01294791, -0.00496563, -0.01810975,
#          -0.04086317, -0.0301403 , -0.04820723, -0.04665878,
#          -0.04840708,  0.01045652,  0.0230119 ],
#         [-0.04654127, -0.0299557 , -0.03854125, -0.01054519,
#           0.00097122,  0.04978224, -0.01480284, -0.01021152,
#          -0.01177146,  0.00073574, -0.03215355],
#         [ 0.03945793,  0.01200671,  0.01551251,  0.03963   ,
#          -0.01656766,  0.00567504, -0.04305182, -0.00364845,
#           0.04060947, -0.00280344, -0.00296711]],
#
#        [[-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [ 0.03209147, -0.00561028,  0.00539353,  0.03247753,
#           0.00468925,  0.01512692,  0.04685165,  0.03980324,
#           0.01631924, -0.01047086, -0.02139553],
#         [ 0.02716657,  0.03850276, -0.03751949,  0.04166797,
#          -0.00788311, -0.01884303,  0.02259257, -0.01319508,
#          -0.03009067, -0.0170976 , -0.02252989],
#         [-0.04967133,  0.01294791, -0.00496563, -0.01810975,
#          -0.04086317, -0.0301403 , -0.04820723, -0.04665878,
#          -0.04840708,  0.01045652,  0.0230119 ],
#         [-0.04654127, -0.0299557 , -0.03854125, -0.01054519,
#           0.00097122,  0.04978224, -0.01480284, -0.01021152,
#          -0.01177146,  0.00073574, -0.03215355],
#         [ 0.01781381,  0.0405875 ,  0.0471752 , -0.01336546,
#           0.01514122,  0.04286078,  0.00069959, -0.02162496,
#           0.03303835, -0.04997932, -0.02466992]],
#
#        [[-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.03269963, -0.00937346, -0.00502968,  0.04483199,
#           0.03470219,  0.03389884, -0.00684636,  0.04990207,
#          -0.03841276, -0.01583838,  0.0250742 ],
#         [ 0.0318701 , -0.00532025, -0.00605241, -0.0339821 ,
#          -0.00912648, -0.04877807, -0.04505664, -0.01691036,
#          -0.00612581,  0.03406263, -0.00399526],
#         [ 0.02669151,  0.00355278, -0.02903469,  0.04221255,
#          -0.01178111,  0.01192344, -0.00304542,  0.0122522 ,
#          -0.02651168,  0.03287125,  0.01817545],
#         [ 0.02684161, -0.03010103,  0.03541192,  0.0107309 ,
#          -0.03425664,  0.01833472, -0.04546411,  0.00071859,
#          -0.04674624,  0.04128278,  0.03694728],
#         [ 0.00653886,  0.00917536,  0.0415543 , -0.00065928,
#          -0.01827232,  0.03079678,  0.01856807,  0.04908952,
#          -0.01480031,  0.04330274,  0.00250711]],
#
#        [[-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01639842,  0.00934479,  0.00453038,  0.04764483,
#           0.01264066, -0.00127489, -0.04397267,  0.01149098,
#          -0.02234172,  0.01894848,  0.0120212 ],
#         [-0.01725036,  0.02072058, -0.03440329, -0.02697587,
#          -0.04808265,  0.00447739, -0.00854848, -0.04052598,
#          -0.04126674,  0.00283849, -0.0244395 ],
#         [-0.01900504, -0.02711363, -0.03646541, -0.0351047 ,
#           0.03256232,  0.01267702,  0.01748389,  0.00157168,
#           0.04225364,  0.03206216,  0.02258629],
#         [-0.03682761,  0.01895275, -0.0146147 ,  0.03220021,
#           0.03617162,  0.04334441, -0.0407308 , -0.03447807,
#           0.04698009,  0.04539349,  0.01660982],
#         [-0.04654127, -0.0299557 , -0.03854125, -0.01054519,
#           0.00097122,  0.04978224, -0.01480284, -0.01021152,
#          -0.01177146,  0.00073574, -0.03215355]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 8017, 5074, 4900, 2628])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 69ms/step
# array([[-0.01639842,  0.00934479,  0.00453038,  0.04764483,  0.01264066,
#         -0.00127489, -0.04397267,  0.01149098, -0.02234172,  0.01894848,
#          0.0120212 ],
#        [-0.01639842,  0.00934479,  0.00453038,  0.04764483,  0.01264066,
#         -0.00127489, -0.04397267,  0.01149098, -0.02234172,  0.01894848,
#          0.0120212 ],
#        [-0.01639842,  0.00934479,  0.00453038,  0.04764483,  0.01264066,
#         -0.00127489, -0.04397267,  0.01149098, -0.02234172,  0.01894848,
#          0.0120212 ],
#        [-0.01639842,  0.00934479,  0.00453038,  0.04764483,  0.01264066,
#         -0.00127489, -0.04397267,  0.01149098, -0.02234172,  0.01894848,
#          0.0120212 ],
#        [ 0.0318701 , -0.00532025, -0.00605241, -0.0339821 , -0.00912648,
#         -0.04877807, -0.04505664, -0.01691036, -0.00612581,  0.03406263,
#         -0.00399526],
#        [-0.01703254,  0.04785147,  0.02648509, -0.00462043,  0.02795117,
#          0.03423065, -0.03556865, -0.00616516,  0.03057313, -0.0242242 ,
#         -0.03303735],
#        [ 0.02684161, -0.03010103,  0.03541192,  0.0107309 , -0.03425664,
#          0.01833472, -0.04546411,  0.00071859, -0.04674624,  0.04128278,
#          0.03694728],
#        [ 0.00308528,  0.03357005,  0.01008511,  0.00702189,  0.01246371,
#         -0.02947147,  0.00230737, -0.03540866,  0.01437571,  0.0148119 ,
#          0.00897276]], dtype=float32)
